# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"//home//kera//Documents//netfix_cleaned.csv")

# %% [markdown]
# # Data Overview

# %%
df
# Out:
#                         names  release_year maturity_rating duration  \
# 0               Mission Majnu          2023        U/A 16+     2h 9m
# 1                      Cirkus          2022         U/A 7+    2h 14m
# 2         Gangubai Kathiawadi          2022        U/A 16+    2h 33m
# 3                     Thunivu          2023        U/A 16+    2h 22m
# 4           Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
# ..                        ...           ...             ...      ...
# 555            Happy New Year          2014        U/A 13+    2h 58m
# 556               RRR (Hindi)          2022              A     3h 5m
# 557            Major (Telugu)          2022        U/A 16+    2h 25m
# 558              Om Shanti Om          2007        U/A 16+    2h 48m
# 559  Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
#
#                                            description  \
# 0    In the 1970s, an undercover Indian spy takes o...
# ...

# %%
df.shape
# Out:
# (560, 10)

# %%
df.columns
# Out:
# Index(['names', 'release_year', 'maturity_rating', 'duration', 'description',
#        'genre', 'mood', 'cast', 'subtitles', 'audio'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   names            560 non-null    object
#  1   release_year     560 non-null    int64
#  2   maturity_rating  560 non-null    object
#  3   duration         560 non-null    object
#  4   description      560 non-null    object
#  5   genre            560 non-null    object
#  6   mood             517 non-null    object
#  7   cast             560 non-null    object
#  8   subtitles        560 non-null    object
#  9   audio            560 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 43.9+ KB

# %%
df.describe()
# Out:
#        release_year
# count    560.000000
# mean    2016.521429
# std        6.282517
# min     1993.000000
# 25%     2012.000000
# 50%     2019.000000
# 75%     2022.000000
# max     2023.000000

# %% [markdown]
# # Data Cleaning

# %%
df.duplicated().sum()
# Out:
# 312

# %%
df.sort_values("names", inplace=True)

# %%
df.drop_duplicates(subset="names", keep=False, inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop("description", axis=1)
df = df.drop("mood", axis=1)

# %%
df
# Out:
#                         names  release_year maturity_rating duration  \
# 539                  18 Pages          2022        U/A 13+    2h 17m
# 384                       300          2007              A    1h 56m
# 51     300: Rise of an Empire          2014              A    1h 42m
# 78                   47 Ronin          2013        U/A 16+    1h 58m
# 313             A Quiet Place          2018        U/A 16+    1h 31m
# ..                        ...           ...             ...      ...
# 3                     Thunivu          2023        U/A 16+    2h 22m
# 32                       Vadh          2022        U/A 16+    1h 49m
# 132          White House Down          2013        U/A 16+    2h 11m
# 48          Wonder Woman 1984          2020        U/A 13+    2h 31m
# 38   Zindagi Na Milegi Dobara          2011        U/A 13+    2h 34m
#
#                                                  genre  \
# 539                      ['Dramas', 'Romantic Movies']
# ...

# %%
df.sort_values(by=['release_year'])
# Out:
#                                names  release_year maturity_rating duration  \
# 291                Final Destination          2000              A    1h 37m
# 75                 Jurassic Park III          2001        U/A 16+    1h 32m
# 104                            Shrek          2001         U/A 7+    1h 30m
# 559         Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
# 338  The SpongeBob SquarePants Movie          2004         U/A 7+    1h 28m
# ..                               ...           ...             ...      ...
# 539                         18 Pages          2022        U/A 13+    2h 17m
# 0                      Mission Majnu          2023        U/A 16+     2h 9m
# 179                       The Strays          2023        U/A 16+    1h 37m
# 3                            Thunivu          2023        U/A 16+    2h 22m
# 175                  Call Me Chihiro          2023        U/A 16+    2h 11m
#
# ...

# %% [markdown]
# # Data visualization

# %%
df['release_year'].hist(bins=20)
plt.xlabel('Movie relased year')
plt.ylabel('Frequency')
plt.title('Frequency of relased movies over year')
plt.show()

# %%
df['maturity_rating'].hist()
plt.xlabel('Maturity_rating')
plt.ylabel('Frequency')
plt.title('Frequency of relased maturity_rating')
plt.show()

# %%
x_axis = df['release_year'] 
y_axis = df['maturity_rating']

plt.bar(df['release_year'], df['maturity_rating'])
plt.title('release_year vs maturity_rating')
plt.xlabel('release_year')
plt.ylabel('maturity_rating')
plt.show()

# %%
# Replace non-numeric characters and convert to float
df['duration'] = df['duration'].str.replace('[^\\d.]', '', regex=True).astype(float)

# %%
x_axis = df['duration']
y_axis = df['maturity_rating']
#plt.figure(figsize=(10, 16))
plt.bar(df['maturity_rating'],df['duration'])
plt.title('maturity_rating vs duration')
plt.xlabel('maturity_rating ')
plt.ylabel('duration')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df['duration'],df['maturity_rating'])
plt.title('duration vs maturity_rating')
plt.ylabel('maturity_rating ')
plt.xlabel('duration')
plt.show()
